# %%
import cv2

# %%
img = cv2.imread('003.jpg')

# %%
cv2.imshow('image',img)

# %%
img = cv2.resize(img,(200,200))

# %%
img = cv2.rotate(img,cv2.cv2.ROTATE)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 img = cv2.rotate(img,cv2.cv2.ROTATE)
#
# AttributeError: module 'cv2' has no attribute 'cv2'

# %%
cv2.imwrite('new-img.jpg',img)
# Out:
# True
