# %%
from ultralytics import YOLO
import cv2
from pathlib import Path

# %%
model = YOLO("comic-speech-bubble-detector.pt")

# %%
image_path = "003.jpg"

# %%
results = model(image_path)
# Out:
# image 1/1 c:\Users\majd\Desktop\pfe project\003.jpg: 1024x736 12 text_bubbles, 1303.7ms
# Speed: 29.6ms preprocess, 1303.7ms inference, 20.8ms postprocess per image at shape (1, 3, 1024, 736)

# %%
annotated_image = results[0].plot()

# %%
output_path = "bubbles_detected.jpg"
cv2.imwrite(output_path, annotated_image)
print(f"Saved result to: {output_path}")
# Out:
# Saved result to: bubbles_detected.jpg
